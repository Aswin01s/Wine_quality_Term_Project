# %%
import pandas as pd
# Load the dataset to inspect it
file_path = 'C:\\Users\\Dinesh KD\\Downloads\\unclean_winequality_red.csv'
df = pd.read_csv(file_path)

# Display first few rows of the dataset to understand its structure
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1          -10.0              0.88         0.00             2.6      0.098
# 2            7.8              0.76          NaN             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0      NaN  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3    100.0        6
# 4      9.4        5

# %%
# 1. Check for missing values in the dataset
missing_values = df.isnull().sum()

# 2. Check for outliers and invalid values (e.g., negative values, extreme outliers)
summary_stats = df.describe()

missing_values, summary_stats
# Out:
# (fixed acidity           0
#  volatile acidity        0
#  citric acid             1
#  residual sugar          0
#  chlorides               0
#  free sulfur dioxide     0
#  total sulfur dioxide    0
#  density                 1
#  pH                      0
#  sulphates               0
#  alcohol                 0
#  quality                 0
#  dtype: int64,
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
#  count    1600.000000       1600.000000  1599.000000     1600.000000
#  mean        8.307938          0.527928     0.270951        2.538406
#  std         1.799897          0.179055     0.194833        1.409578
#  min       -10.000000          0.120000     0.000000        0.900000
#  25%         7.100000          0.390000     0.090000        1.900000
#  50%         7.900000          0.520000     0.260000        2.200000
#  75%         9.200000          0.640000     0.420000        2.600000
#  max        15.900000          1.580000     1.000000       15.500000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide      density  \
#  count  1600.000000          1600.000000           1600.000000  1599.000000
#  mean      0.087459            15.871875             46.460000     0.996747
#  std       0.047051            10.457596             32.886514     0.001887
#  min       0.012000             1.000000              6.000000     0.990070
#  25%       0.070000             7.000000             22.000000     0.995600
#  50%       0.079000            14.000000             38.000000     0.996750
#  75%       0.090000            21.000000             62.000000     0.997835
#  max       0.611000            72.000000            289.000000     1.003690
#
#                  pH    sulphates      alcohol      quality
#  count  1600.000000  1600.000000  1600.000000  1600.000000
#  mean      3.311238     0.658088    10.478719     5.636250
#  std       0.154418     0.169472     2.480001     0.807368
#  min       2.740000     0.330000     8.400000     3.000000
#  25%       3.210000     0.550000     9.500000     5.000000
#  50%       3.310000     0.620000    10.200000     6.000000
#  75%       3.400000     0.730000    11.100000     6.000000
#  max       4.010000     2.000000   100.000000     8.000000  )

# %%
# Step 1: Impute missing values with the median for "citric acid" and "density"
df['citric acid'].fillna(df['citric acid'].median(), inplace=True)
df['density'].fillna(df['density'].median(), inplace=True)

# Step 2: Remove rows with unrealistic or negative values
wine_data_cleaned = df[(df['fixed acidity'] > 0) & (df['alcohol'] < 20)]  # Limiting alcohol to below 20% as a reasonable range for wines

# Step 3: Verify the cleaning by displaying summary statistics and missing values
cleaned_missing_values = wine_data_cleaned.isnull().sum()
cleaned_summary_stats = wine_data_cleaned.describe()

cleaned_missing_values, cleaned_summary_stats
# Out:
# (fixed acidity           0
#  volatile acidity        0
#  citric acid             0
#  residual sugar          0
#  chlorides               0
#  free sulfur dioxide     0
#  total sulfur dioxide    0
#  density                 0
#  pH                      0
#  sulphates               0
#  alcohol                 0
#  quality                 0
#  dtype: int64,
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
#  count    1598.000000       1598.000000  1598.000000     1598.000000
#  mean        8.317584          0.527863     0.270932        2.538767
#  std         1.740252          0.178843     0.194642        1.410369
#  min         4.600000          0.120000     0.000000        0.900000
#  25%         7.100000          0.390000     0.090000        1.900000
#  50%         7.900000          0.520000     0.260000        2.200000
#  75%         9.200000          0.640000     0.420000        2.600000
#  max        15.900000          1.580000     1.000000       15.500000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide      density  \
#  count  1598.000000          1598.000000           1598.000000  1598.000000
#  mean      0.087461            15.865457             46.438673     0.996746
#  std       0.047079            10.461609             32.901334     0.001888
#  min       0.012000             1.000000              6.000000     0.990070
#  25%       0.070000             7.000000             22.000000     0.995600
#  50%       0.079000            14.000000             38.000000     0.996750
#  75%       0.090000            21.000000             62.000000     0.997830
#  max       0.611000            72.000000            289.000000     1.003690
#
#                  pH    sulphates      alcohol      quality
#  count  1598.000000  1598.000000  1598.000000  1598.000000
#  mean      3.311402     0.658123    10.423123     5.636421
#  std       0.154443     0.169566     1.066081     0.807665
#  min       2.740000     0.330000     8.400000     3.000000
#  25%       3.210000     0.550000     9.500000     5.000000
#  50%       3.310000     0.620000    10.200000     6.000000
#  75%       3.400000     0.730000    11.100000     6.000000
#  max       4.010000     2.000000    14.900000     8.000000  )
